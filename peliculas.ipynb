# %% [markdown]
# ## CRÍTICAS DE PELÍCULAS

# %%
# librerías

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Data Frame con las opinioones (de 0 a 5) obtenidas de las críticas de una película.

# %%
df_votantes = {"Opinión (Xi)": [5,4,3,2,1,0], "Cantidad de votantes (Ni)": [40, 99,145,133,96,40]}
df_votantes = pd.DataFrame(df_votantes)
df_votantes
# Out:
#    Opinión (Xi)  Cantidad de votantes (Ni)
# 0             5                         40
# 1             4                         99
# 2             3                        145
# 3             2                        133
# 4             1                         96
# 5             0                         40

# %% [markdown]
# Representación gráfica de los datos

# %%
plt.figure(figsize=(8, 6))

# Graficar los datos en un gráfico de barras
plt.bar(df_votantes['Opinión (Xi)'], df_votantes['Cantidad de votantes (Ni)'])

# Agregar una línea que una todas las barras
plt.plot(df_votantes['Opinión (Xi)'], df_votantes['Cantidad de votantes (Ni)'], color='red')

# Configurar etiquetas y título del gráfico
plt.xlabel('Opinión (Xi)')
plt.ylabel('Cantidad de votantes (Ni)')
plt.title('Gráfico de barras con línea de unión')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Las opiniones corresponden a nuestros valores observados denominados Xi, y la cantidad de votantes se equipara a la cantidad de veces en que el valor observado ha sido elegido por los espectadores. Entonces hablamos de frecuencia de elección, que se denomina Ni.
#
# A fin de calcular la media de esta serie de observaciones, para cada observación hay que realizar el producto de las opiniones por la cantidad de votantes:

# %%
df_votantes["Productos"] = df_votantes["Opinión (Xi)"] * df_votantes["Cantidad de votantes (Ni)"]
df_votantes
# Out:
#    Opinión (Xi)  Cantidad de votantes (Ni)  Productos
# 0             5                         40        200
# 1             4                         99        396
# 2             3                        145        435
# 3             2                        133        266
# 4             1                         96         96
# 5             0                         40          0

# %% [markdown]
# Luego hay que sumar los productos, a continuación sumar las frecuencias y la media se calcula obteniendo la relación entre estos dos valores:

# %%
suma_prod = df_votantes["Productos"].sum()
suma_frec = df_votantes["Cantidad de votantes (Ni)"].sum()

media = suma_prod / suma_frec

print("Media: ", round(media,3))
# Out:
# Media:  2.519

# %% [markdown]
# Ahora vamos a pasar al cálculo de la varianza. Para cada observación obtendremos el producto de la frecuencia por la diferencia elevada al cuadrado entre el valor observado y la media.
#
# Por ejemplo, para la primera observación tenemos:
#
# 40*((5 - 2,51)2) = 246,21

# %%
df_votantes["Ni * ((Xi-media)2)"] = round(df_votantes["Cantidad de votantes (Ni)"] * (df_votantes["Opinión (Xi)"] - media)**2,3)
df_votantes
# Out:
#    Opinión (Xi)  Cantidad de votantes (Ni)  Productos  Ni * ((Xi-media)2)
# 0             5                         40        200             246.217
# 1             4                         99        396             217.146
# 2             3                        145        435              33.549
# 3             2                        133        266              35.823
# 4             1                         96         96             221.503
# 5             0                         40          0             253.812

# %% [markdown]
# Esto nos permite calcular la varianza haciendo la suma de la columna que acabamos de crear dividida entre la suma de las frecuencias:
#
# Varianza = (246,21 + 217,14 + 33,54 + 35,82 + 221,50 + 253,81)/553 = 1,82

# %%
varianza = df_votantes["Ni * ((Xi-media)2)"].sum() / suma_frec
print("Varianza: ", round(varianza, 3))
# Out:
# Varianza:  1.823

# %% [markdown]
# Por último, podemos terminar con la desviación típica calculando la raíz cuadrada de la varianza:

# %%
desv_tipica = np.sqrt(varianza)
print("Desviación típica", round(desv_tipica,3))
# Out:
# Desviación típica 1.35

# %% [markdown]
# Ahora le toca a usted examinar el reparto de las observaciones en función de las desviaciones entre la media y la desviación típica que permite definir los 68 %, 95 % y 97 % de repartos.
#
# Como ejemplo, podemos comprobar que el 68 % de las observaciones están comprendidas en el intervalo [1,3]. Los límites del intervalo se han determinado mediante la resta de la desviación típica a la media para el límite inferior y la suma de la desviación típica a la media para el límite superior. Lo que nos da los siguientes resultados:
#
# - Cantidad de observaciones total: 553
#
# - Cantidad de observaciones comprendidas entre 1 y 3 = 145 + 133 + 96 = 374
#
# - Un porcentaje de 374/553 = 67,63 %

# %%
# 68%
